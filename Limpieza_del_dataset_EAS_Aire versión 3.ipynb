# %% [markdown]
# ## Objetivo
#
# Realizar la limpieza del conjunto de datos **Evaluaciones Ambientales de Seguimiento (EAS) - Aire**
# del OEFA a partir de los problemas identificados durante la etapa de exploración.
#
# Las principales decisiones de limpieza son:
#
# - Trabajar con registros correspondientes al periodo 2022-2024.
# - Utilizar mediciones con periodicidad de una hora.
# - Seleccionar los contaminantes PM10, PM2.5, SO2, NO2 y CO.
# - Conservar únicamente valores cuantitativos válidos.
# - Homogeneizar las unidades µg/m³ y μg/m³.
# - Excluir registros expresados en ppb para evitar mezclar escalas diferentes.
# - Eliminar concentraciones negativas.
# - Estandarizar los nombres de las variables y contaminantes.
# - Revisar y eliminar únicamente registros exactamente duplicados.

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install duckdb -q

# %%
import os
import duckdb
import pandas as pd

ARCHIVO = "/content/drive/MyDrive/Concurrente/EAS_Aire_0.csv"

CARPETA_SALIDA = "/content/drive/MyDrive/Concurrente/Procesado"

os.makedirs(CARPETA_SALIDA, exist_ok=True)

con = duckdb.connect()

# %% [markdown]
# ## 2. Carga del dataset original

# %%
con.execute(f"""
CREATE OR REPLACE VIEW eas_original AS

SELECT *
FROM read_csv_auto(
    '{ARCHIVO}',
    sample_size=100000
);
""")

print("Vista 'eas_original' creada correctamente.")
# Out:
# Vista 'eas_original' creada correctamente.

# %% [markdown]
# ## 3. Verificación inicial

# %%
TOTAL_ORIGINAL = con.execute("""
SELECT COUNT(*)
FROM eas_original
""").fetchone()[0]

print(f"Registros originales: {TOTAL_ORIGINAL:,}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Registros originales: 11,407,394

# %% [markdown]
# ## 4. Estandarización inicial de variables
#
# Se crea una representación intermedia del dataset con nombres de columnas más simples
# y tipos de datos adecuados.
#
# La fecha almacenada en formato serial de Excel se transforma a una fecha convencional.
# La hora se convierte al tipo temporal correspondiente y la columna `Valor` se intenta
# convertir a un valor numérico.

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_base AS

SELECT
    TRIM("Número.de.informe") AS numero_informe,
    TRIM("Nombre.de.la.Evaluación") AS nombre_evaluacion,

    TRIM("Nombre.del.punto") AS punto,

    TRY_CAST("Este" AS DOUBLE) AS este,
    TRY_CAST("Norte" AS DOUBLE) AS norte,
    TRY_CAST("Altitud" AS DOUBLE) AS altitud,
    TRY_CAST("Zona" AS INTEGER) AS zona,

    TRIM("Datum") AS datum,

    TRIM("Tipo.de.análisis") AS tipo_analisis,
    TRIM("Periodo") AS periodo,

    DATE '1899-12-30'
        + CAST(
            TRY_CAST("Fecha.inicio" AS DOUBLE)
            AS INTEGER
        ) AS fecha,

    TRY_CAST(
        NULLIF(TRIM("Hora.inicio"), '-')
        AS TIME
    ) AS hora,

    TRIM("Parámetro") AS parametro_original,

    TRIM("Unidad.de.medida") AS unidad_original,

    TRY_CAST(
        REPLACE(TRIM("Valor"), ',', '.')
        AS DOUBLE
    ) AS valor

FROM eas_original;
""")

print("Estandarización inicial completada.")
# Out:
# Estandarización inicial completada.

# %% [markdown]
# ## 5. Selección del periodo reciente
#
# El dataset original contiene observaciones desde 2018 hasta 2024.
#
# Para trabajar con información reciente se conservan únicamente los registros comprendidos entre el 1 de enero de 2022 y el 31 de diciembre de 2024.

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_fecha AS

SELECT *
FROM etapa_base

WHERE fecha >= DATE '2022-01-01'
  AND fecha < DATE '2025-01-01';
""")

# %%
TOTAL_FECHA = con.execute("""
SELECT COUNT(*)
FROM etapa_fecha
""").fetchone()[0]

print(f"Antes del filtro: {TOTAL_ORIGINAL:,}")
print(f"Después del filtro 2022-2024: {TOTAL_FECHA:,}")
print(f"Registros eliminados: {TOTAL_ORIGINAL - TOTAL_FECHA:,}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Antes del filtro: 11,407,394
# Después del filtro 2022-2024: 9,138,388
# Registros eliminados: 2,269,006

# %% [markdown]
# ## 6. Homogeneización de los nombres de los contaminantes
#
# - El dataset contiene diferentes formas de representar algunos parámetros ambientales.
#
# - Se clasifican las mediciones correspondientes a los cinco contaminantes seleccionados: PM10, PM2.5, SO2, NO2 y CO.
#
# - Los demás parámetros ambientales se mantienen fuera del conjunto destinado al caso de uso.

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_contaminantes AS

SELECT
    *,

    CASE

        -- PM2.5 se evalúa antes que PM10 para evitar clasificaciones incorrectas.
        WHEN
            LOWER(parametro_original) LIKE '%pm2,5%'
            OR LOWER(parametro_original) LIKE '%pm2.5%'
            OR LOWER(parametro_original) LIKE '%2,5%'
            OR LOWER(parametro_original) LIKE '%2.5%'
        THEN 'PM2.5'

        WHEN (
            LOWER(parametro_original) LIKE '%pm10%'
            OR (
                LOWER(parametro_original) LIKE '%particul%'
                AND LOWER(parametro_original) LIKE '%10%'
            )
        )
        THEN 'PM10'

        WHEN LOWER(parametro_original)
             LIKE '%dióxido de azufre%'
        THEN 'SO2'

        WHEN LOWER(parametro_original)
             LIKE '%dióxido de nitrógeno%'
        THEN 'NO2'

        WHEN LOWER(parametro_original)
             LIKE '%monóxido de carbono%'
        THEN 'CO'

        ELSE NULL

    END AS contaminante

FROM etapa_fecha;
""")

# %%
resumen_clasificacion = con.execute("""
SELECT
    contaminante,
    COUNT(*) AS registros
FROM etapa_contaminantes
WHERE contaminante IS NOT NULL
GROUP BY contaminante
ORDER BY registros DESC
""").df()

display(resumen_clasificacion)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#   contaminante  registros
# 0          SO2     936186
# 1         PM10     735162
# 2        PM2.5     634747
# 3           CO     429528
# 4          NO2     260806

# %% [markdown]
# ## 7. Selección de contaminantes
#
# Se eliminan del conjunto de trabajo los parámetros que no corresponden a PM10, PM2.5,
# SO2, NO2 o CO.
#
# Esta selección responde al caso de uso planteado para analizar patrones de contaminación atmosférica.

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_parametros AS

SELECT *
FROM etapa_contaminantes

WHERE contaminante IS NOT NULL;
""")

# %%
TOTAL_PARAMETROS = con.execute("""
SELECT COUNT(*)
FROM etapa_parametros
""").fetchone()[0]

print(f"Registros con contaminantes seleccionados: {TOTAL_PARAMETROS:,}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Registros con contaminantes seleccionados: 2,996,429

# %% [markdown]
# ## 8. Eliminación de valores no cuantificables
#
# Durante la exploración se identificaron valores como `-`, `NA`, `N.D.`, `<LC`, `<L.D.`,
# códigos alfabéticos y otras representaciones que no corresponden directamente a una
# concentración numérica.
#
# Para el conjunto destinado al modelo se conservan únicamente las observaciones que
# pueden interpretarse directamente como valores cuantitativos.

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_numericos AS

SELECT *
FROM etapa_parametros

WHERE valor IS NOT NULL;
""")

# %%
TOTAL_NUMERICOS = con.execute("""
SELECT COUNT(*)
FROM etapa_numericos
""").fetchone()[0]

print(f"Antes del filtro numérico: {TOTAL_PARAMETROS:,}")
print(f"Valores numéricos válidos: {TOTAL_NUMERICOS:,}")
print(f"No numéricos excluidos: {TOTAL_PARAMETROS - TOTAL_NUMERICOS:,}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Antes del filtro numérico: 2,996,429
# Valores numéricos válidos: 1,994,760
# No numéricos excluidos: 1,001,669

# %% [markdown]
# ## 9. Homogeneización de la periodicidad
#
# El dataset contiene mediciones realizadas en periodos diferentes, como una hora,
# tres horas móviles, ocho horas móviles y veinticuatro horas.
#
# Para evitar mezclar observaciones con distinta resolución temporal se seleccionan
# únicamente mediciones correspondientes a un periodo de una hora.

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_1hora AS

SELECT *
FROM etapa_numericos

WHERE LOWER(TRIM(periodo)) = '1 hora';
""")

# %%
TOTAL_1H = con.execute("""
SELECT COUNT(*)
FROM etapa_1hora
""").fetchone()[0]

print(f"Registros numéricos antes del filtro: {TOTAL_NUMERICOS:,}")
print(f"Mediciones de 1 hora: {TOTAL_1H:,}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Registros numéricos antes del filtro: 1,994,760
# Mediciones de 1 hora: 1,670,191

# %% [markdown]
# ## 10. Homogeneización de unidades de medida
#
# Se identificaron dos representaciones visualmente similares de microgramos por metro
# cúbico: `µg/m³` y `μg/m³`.
#
# Ambas representan la misma unidad y son estandarizadas como `µg/m³`.
#
# Las mediciones expresadas en `ppb` no se convierten, ya que esto requeriría
# conversiones específicas para cada compuesto y condiciones físicas adicionales.

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_unidades AS

SELECT
    *,

    CASE
        WHEN TRIM(unidad_original) IN ('µg/m³', 'μg/m³')
        THEN 'µg/m³'

        ELSE TRIM(unidad_original)
    END AS unidad

FROM etapa_1hora;
""")

# %%
unidades = con.execute("""
SELECT
    contaminante,
    unidad,
    COUNT(*) AS registros

FROM etapa_unidades

GROUP BY contaminante, unidad
ORDER BY contaminante, registros DESC
""").df()

display(unidades)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#   contaminante unidad  registros
# 0           CO  µg/m³      77114
# 1           CO    ppb      77114
# 2          NO2  µg/m³      85094
# 3          NO2    ppb      85094
# 4         PM10  µg/m³     466808
# 5        PM2.5  µg/m³     423496
# 6          SO2  µg/m³     240664
# 7          SO2    ppb     214807

# %% [markdown]
# ## 11. Selección de una unidad común
#
# Para garantizar que las concentraciones utilizadas en el conjunto final se encuentren
# expresadas mediante una misma unidad física, se conservan únicamente las mediciones
# registradas en microgramos por metro cúbico (`µg/m³`).

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_microgramos AS

SELECT *
FROM etapa_unidades

WHERE unidad = 'µg/m³';
""")

# %%
TOTAL_MICROGRAMOS = con.execute("""
SELECT COUNT(*)
FROM etapa_microgramos
""").fetchone()[0]

print(f"Mediciones horarias antes del filtro de unidad: {TOTAL_1H:,}")
print(f"Mediciones en µg/m³: {TOTAL_MICROGRAMOS:,}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Mediciones horarias antes del filtro de unidad: 1,670,191
# Mediciones en µg/m³: 1,293,176

# %% [markdown]
# ## 12. Validación de las concentraciones
#
# Las concentraciones de contaminantes atmosféricos no deben presentar valores negativos.
#
# Se analiza si existen concentraciones menores que cero antes de eliminarlas.
# Los valores elevados no se eliminan automáticamente porque podrían representar eventos
# ambientales reales y no necesariamente errores.

# %%
valores_negativos = con.execute("""
SELECT
    contaminante,
    COUNT(*) AS negativos,
    MIN(valor) AS valor_minimo

FROM etapa_microgramos

WHERE valor < 0

GROUP BY contaminante
ORDER BY negativos DESC
""").df()

display(valores_negativos)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Empty DataFrame
# Columns: [contaminante, negativos, valor_minimo]
# Index: []

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_valores_validos AS

SELECT *
FROM etapa_microgramos

WHERE valor >= 0;
""")

print("Vista 'etapa_valores_validos' creada correctamente.")
# Out:
# Vista 'etapa_valores_validos' creada correctamente.

# %%
TOTAL_VALIDOS = con.execute("""
SELECT COUNT(*)
FROM etapa_valores_validos
""").fetchone()[0]

print(f"Antes de validar concentraciones: {TOTAL_MICROGRAMOS:,}")
print(f"Después de eliminar valores negativos: {TOTAL_VALIDOS:,}")
print(f"Valores negativos eliminados: {TOTAL_MICROGRAMOS - TOTAL_VALIDOS:,}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Antes de validar concentraciones: 1,293,176
# Después de eliminar valores negativos: 1,293,176
# Valores negativos eliminados: 0

# %% [markdown]
# ## 13. Validación de información espacial
#
# El caso de uso considera patrones espaciales, por lo que se verifica que las observaciones
# dispongan de punto de monitoreo y coordenadas válidas.
#
# No se eliminan valores de altitud iguales a cero, ya que pueden ser válidos en zonas
# ubicadas cerca del nivel del mar.

# %%
problemas_espaciales = con.execute("""
SELECT
    COUNT(*) FILTER (
        WHERE punto IS NULL
           OR TRIM(punto) = ''
           OR TRIM(punto) = '-'
    ) AS punto_invalido,

    COUNT(*) FILTER (
        WHERE este IS NULL OR este <= 0
    ) AS este_invalido,

    COUNT(*) FILTER (
        WHERE norte IS NULL OR norte <= 0
    ) AS norte_invalido,

    COUNT(*) FILTER (
        WHERE zona IS NULL
    ) AS zona_invalida

FROM etapa_valores_validos;
""").df()

display(problemas_espaciales)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    punto_invalido  este_invalido  norte_invalido  zona_invalida
# 0               0              0               0              0

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_espacial AS

SELECT *
FROM etapa_valores_validos

WHERE punto IS NOT NULL
  AND TRIM(punto) <> ''
  AND TRIM(punto) <> '-'

  AND este IS NOT NULL
  AND este > 0

  AND norte IS NOT NULL
  AND norte > 0

  AND zona IS NOT NULL;
""")

# %%
TOTAL_ESPACIAL = con.execute("""
SELECT COUNT(*)
FROM etapa_espacial
""").fetchone()[0]

print(f"Antes de validar ubicación: {TOTAL_VALIDOS:,}")
print(f"Después de validar ubicación: {TOTAL_ESPACIAL:,}")
print(f"Registros eliminados: {TOTAL_VALIDOS - TOTAL_ESPACIAL:,}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Antes de validar ubicación: 1,293,176
# Después de validar ubicación: 1,293,176
# Registros eliminados: 0

# %% [markdown]
# ## 14. Identificación de registros duplicados
#
# Se buscan observaciones exactamente repetidas considerando la información necesaria
# para identificar una medición.
#
# No se consideran duplicadas dos mediciones únicamente porque posean la misma concentración;
# deben coincidir también el informe, punto, fecha, hora, contaminante, ubicación y valor.

# %%
duplicados = con.execute("""
SELECT
    SUM(cantidad - 1) AS duplicados_exactos

FROM (
    SELECT
        numero_informe,
        nombre_evaluacion,
        punto,
        este,
        norte,
        altitud,
        zona,
        datum,
        fecha,
        hora,
        contaminante,
        unidad,
        valor,

        COUNT(*) AS cantidad

    FROM etapa_espacial

    GROUP BY
        numero_informe,
        nombre_evaluacion,
        punto,
        este,
        norte,
        altitud,
        zona,
        datum,
        fecha,
        hora,
        contaminante,
        unidad,
        valor

    HAVING COUNT(*) > 1
);
""").df()

display(duplicados)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    duplicados_exactos
# 0             46905.0

# %% [markdown]
# ## 15. Eliminación de duplicados exactos
#
# Una vez cuantificados los duplicados, se conserva una única instancia de las observaciones que son completamente idénticas según las variables seleccionadas.

# %%
con.execute("""
CREATE OR REPLACE VIEW etapa_sin_duplicados AS

SELECT DISTINCT
    numero_informe,
    nombre_evaluacion,

    punto,

    este,
    norte,
    altitud,
    zona,
    datum,

    fecha,
    hora,

    contaminante,
    unidad,
    valor

FROM etapa_espacial;
""")

# %%
TOTAL_SIN_DUPLICADOS = con.execute("""
SELECT COUNT(*)
FROM etapa_sin_duplicados
""").fetchone()[0]

print(f"Antes de eliminar duplicados: {TOTAL_ESPACIAL:,}")
print(f"Después: {TOTAL_SIN_DUPLICADOS:,}")
print(f"Duplicados eliminados: {TOTAL_ESPACIAL - TOTAL_SIN_DUPLICADOS:,}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Antes de eliminar duplicados: 1,293,176
# Después: 1,246,271
# Duplicados eliminados: 46,905

# %% [markdown]
# ## 16. Dataset limpio
#
# Se genera la vista final con las variables necesarias para conservar la trazabilidad de las mediciones y permitir su posterior preparación para Machine Learning.

# %%
con.execute("""
CREATE OR REPLACE VIEW eas_aire_limpio AS

SELECT
    numero_informe,
    nombre_evaluacion,

    punto,

    este,
    norte,
    altitud,
    zona,
    datum,

    fecha,
    hora,

    contaminante,
    valor AS concentracion,
    unidad

FROM etapa_sin_duplicados;
""")

# %% [markdown]
# ## 17. Verificación del dataset limpio

# %%
muestra_limpia = con.execute("""
SELECT *
FROM eas_aire_limpio
LIMIT 20
""").df()

display(muestra_limpia)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#         numero_informe                                  nombre_evaluacion  \
# 0   REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 1   REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 2   REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 3   REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 4   REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 5   REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 6   REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 7   REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 8   REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 9   REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 10  REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 11  REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 12  REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 13  REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 14  REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 15  REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 16  REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 17  REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 18  REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
# 19  REAS-006-2024-STEC  Calidad del aire en el ámbito de la zona indus...
#
#        punto      este      norte  altitud  zona  datum      fecha      hora  \
# 0   CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  02:00:00
# 1   CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  05:00:00
# 2   CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  07:00:00
# 3   CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  10:00:00
# 4   CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  11:00:00
# 5   CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  14:00:00
# 6   CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  16:00:00
# 7   CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  17:00:00
# 8   CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  19:00:00
# 9   CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  20:00:00
# 10  CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  21:00:00
# 11  CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  22:00:00
# 12  CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  01:00:00
# 13  CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  02:00:00
# 14  CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  04:00:00
# 15  CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  09:00:00
# 16  CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  13:00:00
# 17  CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  15:00:00
# 18  CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  22:00:00
# 19  CA-CH-03  767988.0  8992825.0     15.0    17  WGS84 2023-02-10  23:00:00
#
#    contaminante  concentracion unidad
# 0           SO2          10.51  µg/m³
# 1           SO2          10.22  µg/m³
# 2           SO2          10.43  µg/m³
# 3           SO2          11.19  µg/m³
# 4           SO2          10.87  µg/m³
# 5           SO2          10.27  µg/m³
# 6           SO2          10.74  µg/m³
# 7           SO2          11.08  µg/m³
# 8           SO2          10.72  µg/m³
# 9           SO2          10.69  µg/m³
# 10          SO2          10.35  µg/m³
# 11          SO2          10.17  µg/m³
# 12         PM10          10.91  µg/m³
# 13         PM10          12.30  µg/m³
# 14         PM10           6.58  µg/m³
# 15         PM10          18.92  µg/m³
# 16         PM10          23.82  µg/m³
# 17         PM10          37.67  µg/m³
# 18         PM10          11.20  µg/m³
# 19         PM10          12.07  µg/m³

# %%
esquema_limpio = con.execute("""
DESCRIBE eas_aire_limpio
""").df()

display(esquema_limpio)
# Out:
#           column_name column_type null   key default extra
# 0      numero_informe     VARCHAR  YES  None    None  None
# 1   nombre_evaluacion     VARCHAR  YES  None    None  None
# 2               punto     VARCHAR  YES  None    None  None
# 3                este      DOUBLE  YES  None    None  None
# 4               norte      DOUBLE  YES  None    None  None
# 5             altitud      DOUBLE  YES  None    None  None
# 6                zona     INTEGER  YES  None    None  None
# 7               datum     VARCHAR  YES  None    None  None
# 8               fecha        DATE  YES  None    None  None
# 9                hora        TIME  YES  None    None  None
# 10       contaminante     VARCHAR  YES  None    None  None
# 11      concentracion      DOUBLE  YES  None    None  None
# 12             unidad     VARCHAR  YES  None    None  None

# %% [markdown]
# ## 18. Distribución final de contaminantes
#
# Se verifica cuántos registros permanecen disponibles para cada contaminante después
# de las principales etapas de limpieza.
#
# También se revisan los valores mínimo, promedio y máximo como una primera evaluación
# de la distribución de las concentraciones.

# %%
distribucion_final = con.execute("""
SELECT
    contaminante,
    COUNT(*) AS registros,

    MIN(concentracion) AS minimo,
    AVG(concentracion) AS promedio,
    MAX(concentracion) AS maximo

FROM eas_aire_limpio

GROUP BY contaminante
ORDER BY registros DESC
""").df()

display(distribucion_final)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#   contaminante  registros  minimo    promedio   maximo
# 0         PM10     461641    0.01   42.567106  6024.55
# 1        PM2.5     413499    0.00   20.799127  1256.30
# 2          SO2     212557    0.47   27.138638  5654.69
# 3          NO2      81804    1.07   13.113193   993.73
# 4           CO      76770   27.67  292.744725  1705.06

# %% [markdown]
# ## 19. Distribución temporal final
#
# Se comprueba que el conjunto limpio conserve observaciones correspondientes a los
# tres años seleccionados: 2022, 2023 y 2024.

# %%
por_anio = con.execute("""
SELECT
    YEAR(fecha) AS anio,
    COUNT(*) AS registros

FROM eas_aire_limpio

GROUP BY YEAR(fecha)
ORDER BY anio
""").df()

display(por_anio)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    anio  registros
# 0  2022     411633
# 1  2023     435356
# 2  2024     399282

# %% [markdown]
# ## 20. Análisis de distribución de concentraciones
#
# Antes de finalizar el proceso de limpieza se analiza la distribución de las concentraciones
# para identificar valores extremos.
#
# Los valores elevados no son eliminados automáticamente, ya que podrían representar eventos
# reales de contaminación. Primero se evalúa su frecuencia y posición dentro de la distribución
# de cada contaminante.

# %%
estadisticas = con.execute("""
SELECT
    contaminante,

    COUNT(*) AS registros,

    MIN(concentracion) AS minimo,

    QUANTILE_CONT(concentracion, 0.25) AS q1,
    MEDIAN(concentracion) AS mediana,
    QUANTILE_CONT(concentracion, 0.75) AS q3,

    QUANTILE_CONT(concentracion, 0.90) AS p90,
    QUANTILE_CONT(concentracion, 0.95) AS p95,
    QUANTILE_CONT(concentracion, 0.99) AS p99,

    AVG(concentracion) AS promedio,
    MAX(concentracion) AS maximo

FROM eas_aire_limpio

GROUP BY contaminante
ORDER BY contaminante;
""").df()

display(estadisticas)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#   contaminante  registros  minimo      q1  mediana      q3      p90       p95  \
# 0           CO      76770   27.67  246.19   281.70  324.83  378.580  433.6555
# 1          NO2      81804    1.07    4.76     7.16   12.09   22.444   50.7000
# 2         PM10     461641    0.01   12.54    24.20   49.83  102.120  146.7900
# 3        PM2.5     413499    0.00    6.70    11.85   21.66   47.880   79.5000
# 4          SO2     212557    0.47    7.60     9.51   19.70   66.310  111.9560
#
#         p99    promedio   maximo
# 0  638.6313  292.744725  1705.06
# 1   88.3185   13.113193   993.73
# 2  250.5660   42.567106  6024.55
# 3  139.7400   20.799127  1256.30
# 4  259.5232   27.138638  5654.69

# %% [markdown]
# ## 21. Revisión de las concentraciones más elevadas
#
# Se inspeccionan las observaciones con mayores concentraciones dentro de cada contaminante.
#
# El objetivo es determinar si los valores elevados corresponden a registros aislados,
# errores evidentes o posibles eventos reales registrados en determinados puntos y fechas.

# %%
top_por_contaminante = con.execute("""
WITH ranking AS (
    SELECT
        numero_informe,
        nombre_evaluacion,
        punto,
        fecha,
        hora,
        contaminante,
        concentracion,
        unidad,

        ROW_NUMBER() OVER (
            PARTITION BY contaminante
            ORDER BY concentracion DESC
        ) AS posicion

    FROM eas_aire_limpio
)

SELECT *
FROM ranking

WHERE posicion <= 20

ORDER BY contaminante, posicion;
""").df()

display(top_por_contaminante)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                           numero_informe  \
# 0                     REAS-003-2024-STEC
# 1                     REAS-003-2024-STEC
# 2                     REAS-003-2024-STEC
# 3                     REAS-003-2024-STEC
# 4                     REAS-003-2024-STEC
# ..                                   ...
# 95                    REAS-012-2025-STEC
# 96                    REAS-012-2025-STEC
# 97                    REAS-012-2025-STEC
# 98  REPORTE N° 00007-2022-OEFA/DEAM-STEC
# 99                    REAS-012-2025-STEC
#
#                                     nombre_evaluacion        punto      fecha  \
# 0   Calidad del aire en el ámbito de influencia de...  CA-PISCO-03 2023-06-02
# 1   Calidad del aire en el ámbito de influencia de...  CA-PISCO-03 2023-06-04
# 2   Calidad del aire en el ámbito de influencia de...  CA-PISCO-03 2023-06-04
# 3   Calidad del aire en el ámbito de influencia de...  CA-PISCO-03 2023-08-09
# 4   Calidad del aire en el ámbito de influencia de...  CA-PISCO-03 2023-08-08
# ..                                                ...          ...        ...
# 95  Calidad del aire en el área de influencia del ...     CA-CC-01 2024-12-08
# 96  Calidad del aire en el área de influencia del ...     CA-CC-01 2024-07-30
# 97  Calidad del aire en el área de influencia del ...     CA-CC-01 2024-09-09
# 98  Calidad del aire en el ámbito de la refinería ...    CA-RZC-02 2022-04-15
# 99  Calidad del aire en el área de influencia del ...     CA-CC-01 2024-12-04
#
#         hora contaminante  concentracion unidad  posicion
# 0   04:00:00           CO        1705.06  µg/m³         1
# 1   01:00:00           CO        1699.72  µg/m³         2
# 2   00:00:00           CO        1407.94  µg/m³         3
# 3   07:00:00           CO        1328.82  µg/m³         4
# 4   22:00:00           CO        1263.26  µg/m³         5
# ..       ...          ...            ...    ...       ...
# 95      <NA>          SO2        1451.09  µg/m³        16
# 96      <NA>          SO2        1441.37  µg/m³        17
# 97      <NA>          SO2        1439.06  µg/m³        18
# 98      <NA>          SO2        1432.96  µg/m³        19
# 99      <NA>          SO2        1421.51  µg/m³        20
#
# [100 rows x 9 columns]

# %% [markdown]
# ## 22. Identificación estadística de valores extremos
#
# Se utiliza el rango intercuartílico (IQR) para identificar observaciones alejadas de la
# distribución típica de cada contaminante.

# %%
outliers_iqr = con.execute("""
WITH limites AS (
    SELECT
        contaminante,

        QUANTILE_CONT(concentracion, 0.25) AS q1,
        QUANTILE_CONT(concentracion, 0.75) AS q3

    FROM eas_aire_limpio

    GROUP BY contaminante
),

datos AS (
    SELECT
        e.*,
        l.q1,
        l.q3,
        (l.q3 - l.q1) AS iqr

    FROM eas_aire_limpio e

    JOIN limites l
      ON e.contaminante = l.contaminante
)

SELECT
    contaminante,

    COUNT(*) AS registros,

    COUNT(*) FILTER (
        WHERE concentracion > q3 + 1.5 * iqr
    ) AS valores_extremos,

    ROUND(
        100.0 *
        COUNT(*) FILTER (
            WHERE concentracion > q3 + 1.5 * iqr
        )
        / COUNT(*),
        2
    ) AS porcentaje_extremos

FROM datos

GROUP BY contaminante
ORDER BY contaminante;
""").df()

display(outliers_iqr)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#   contaminante  registros  valores_extremos  porcentaje_extremos
# 0           CO      76770              3467                 4.52
# 1          NO2      81804              7905                 9.66
# 2         PM10     461641             43665                 9.46
# 3        PM2.5     413499             45504                11.00
# 4          SO2     212557             34184                16.08

# %% [markdown]
# ## 23. Distribución de valores elevados por punto de monitoreo
#
# Se analiza la distribución espacial de las observaciones superiores al percentil 99 de cada
# contaminante.
#
# Si las concentraciones elevadas aparecen repetidamente en determinados puntos y periodos, pueden corresponder a eventos ambientales reales y no necesariamente a errores del dataset.

# %%
extremos_por_punto = con.execute("""
WITH limites AS (
    SELECT
        contaminante,
        QUANTILE_CONT(concentracion, 0.99) AS p99

    FROM eas_aire_limpio

    GROUP BY contaminante
)

SELECT
    e.contaminante,
    e.punto,

    COUNT(*) AS registros_sobre_p99,

    MIN(e.fecha) AS primera_fecha,
    MAX(e.fecha) AS ultima_fecha,

    MAX(e.concentracion) AS maximo

FROM eas_aire_limpio e

JOIN limites l
  ON e.contaminante = l.contaminante

WHERE e.concentracion > l.p99

GROUP BY
    e.contaminante,
    e.punto

ORDER BY
    e.contaminante,
    registros_sobre_p99 DESC;
""").df()

display(extremos_por_punto.head(100))
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    contaminante        punto  registros_sobre_p99 primera_fecha ultima_fecha  \
# 0            CO  CA-PISCO-03                  367    2023-06-02   2023-12-09
# 1            CO  CA-PISCO-01                  272    2023-10-22   2023-12-31
# 2            CO  CA-PISCO-02                  111    2023-07-11   2023-12-10
# 3            CO    CA-ILO-03                   16    2022-01-01   2024-07-05
# 4            CO    CA-ILO-02                    2    2022-10-20   2024-03-26
# ..          ...          ...                  ...           ...          ...
# 63          SO2    CA-ILO-02                   47    2022-01-02   2024-12-23
# 64          SO2    CA-RZC-01                   33    2022-01-06   2024-12-10
# 65          SO2    CA-ILO-03                   18    2022-01-09   2023-04-24
# 66          SO2    CA-ILO-01                   12    2022-01-02   2024-04-10
# 67          SO2     CA-TA-01                    1    2024-08-16   2024-08-16
#
#      maximo
# 0   1705.06
# 1    976.88
# 2   1139.24
# 3    750.80
# 4    720.02
# ..      ...
# 63   520.02
# 64   470.94
# 65   426.54
# 66   605.80
# 67   332.16
#
# [68 rows x 6 columns]

# %% [markdown]
# ## 24. Tratamiento de los valores extremos
#
# El análisis estadístico permitió identificar concentraciones alejadas de la distribución habitual de cada contaminante.
#
# Sin embargo, estos registros no fueron eliminados únicamente por su magnitud. Las evaluaciones ambientales pueden registrar episodios reales de alta concentración y la presencia de un valor extremo estadístico no constituye por sí sola evidencia de un error de medición.
#
# Además, la revisión de las observaciones con mayores concentraciones mostró que estos valores aparecen de manera recurrente en determinados puntos de monitoreo y periodos de tiempo, lo que sugiere la posible ocurrencia de eventos reales de contaminación atmosférica.
#
# Por este motivo, se conservaron las concentraciones elevadas que cumplían las demás condiciones de calidad definidas durante el proceso de limpieza.

# %% [markdown]
# ## 25. Resumen cuantitativo del proceso de limpieza

# %%
resumen_limpieza = pd.DataFrame([
    {
        "etapa": "Dataset original",
        "registros": TOTAL_ORIGINAL
    },
    {
        "etapa": "Periodo 2022-2024",
        "registros": TOTAL_FECHA
    },
    {
        "etapa": "Contaminantes seleccionados",
        "registros": TOTAL_PARAMETROS
    },
    {
        "etapa": "Valores numéricos",
        "registros": TOTAL_NUMERICOS
    },
    {
        "etapa": "Periodicidad de 1 hora",
        "registros": TOTAL_1H
    },
    {
        "etapa": "Unidad µg/m³",
        "registros": TOTAL_MICROGRAMOS
    },
    {
        "etapa": "Concentraciones válidas",
        "registros": TOTAL_VALIDOS
    },
    {
        "etapa": "Información espacial válida",
        "registros": TOTAL_ESPACIAL
    },
    {
        "etapa": "Sin duplicados exactos",
        "registros": TOTAL_SIN_DUPLICADOS
    }
])

resumen_limpieza["eliminados_desde_etapa_anterior"] = (
    resumen_limpieza["registros"].shift(1)
    - resumen_limpieza["registros"]
)

resumen_limpieza["porcentaje_del_original"] = (
    resumen_limpieza["registros"]
    / TOTAL_ORIGINAL
    * 100
).round(2)

display(resumen_limpieza)
# Out:
#                          etapa  registros  eliminados_desde_etapa_anterior  \
# 0             Dataset original   11407394                              NaN
# 1            Periodo 2022-2024    9138388                        2269006.0
# 2  Contaminantes seleccionados    2996429                        6141959.0
# 3            Valores numéricos    1994760                        1001669.0
# 4       Periodicidad de 1 hora    1670191                         324569.0
# 5                 Unidad µg/m³    1293176                         377015.0
# 6      Concentraciones válidas    1293176                              0.0
# 7  Información espacial válida    1293176                              0.0
# 8       Sin duplicados exactos    1246271                          46905.0
#
#    porcentaje_del_original
# 0                   100.00
# 1                    80.11
# 2                    26.27
# 3                    17.49
# 4                    14.64
# 5                    11.34
# 6                    11.34
# 7                    11.34
# 8                    10.93

# %% [markdown]
# ## 26. Verificación del tamaño del dataset resultante

# %%
if TOTAL_SIN_DUPLICADOS > 1_000_000:
    print("✅ El dataset limpio mantiene más de 1,000,000 de registros.")
else:
    print("⚠️ El dataset limpio contiene menos de 1,000,000 de registros.")

print(f"Registros finales: {TOTAL_SIN_DUPLICADOS:,}")
# Out:
# ✅ El dataset limpio mantiene más de 1,000,000 de registros.
# Registros finales: 1,246,271

# %% [markdown]
# ## 27. Exportación del dataset limpio

# %%
SALIDA_CSV = os.path.join(
    CARPETA_SALIDA,
    "EAS_Aire_limpio.csv"
)

SALIDA_PARQUET = os.path.join(
    CARPETA_SALIDA,
    "EAS_Aire_limpio.parquet"
)

# %%
con.execute(f"""
COPY (
    SELECT *
    FROM eas_aire_limpio
)
TO '{SALIDA_CSV}'
(
    HEADER,
    DELIMITER ','
);
""")

print("CSV exportado correctamente.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# CSV exportado correctamente.

# %%
con.execute(f"""
COPY (
    SELECT *
    FROM eas_aire_limpio
)
TO '{SALIDA_PARQUET}'
(
    FORMAT PARQUET,
    COMPRESSION ZSTD
);
""")

print("Parquet exportado correctamente.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Parquet exportado correctamente.

# %% [markdown]
# ## 28. Verificación de archivos generados

# %%
for ruta in [SALIDA_CSV, SALIDA_PARQUET]:

    if os.path.exists(ruta):

        tamano_mb = os.path.getsize(ruta) / (1024**2)

        print(
            f"{os.path.basename(ruta)} "
            f"-> {tamano_mb:.2f} MB"
        )

    else:

        print(
            f"No se encontró: "
            f"{os.path.basename(ruta)}"
        )
# Out:
# EAS_Aire_limpio.csv -> 215.34 MB
# EAS_Aire_limpio.parquet -> 3.75 MB

# %% [markdown]
# ## Resultado final de la limpieza
# El proceso de limpieza permitió transformar el conjunto original de datos en un subconjunto orientado específicamente al análisis de contaminación atmosférica.
#
# Se conservaron únicamente observaciones correspondientes al periodo 2022–2024 y a los contaminantes PM10, PM2.5, SO2, NO2 y CO. Asimismo, se seleccionaron mediciones con periodicidad horaria, expresadas en µg/m³ y con concentraciones que pudieron ser interpretadas como valores numéricos válidos.
#
# Durante la limpieza no se identificaron concentraciones negativas dentro del subconjunto seleccionado y tampoco se detectaron observaciones con información espacial inválida. Adicionalmente, se eliminaron los registros exactamente duplicados para evitar redundancias en los análisis posteriores.
#
# Los valores estadísticamente extremos fueron revisados antes de finalizar el procedimiento. Debido a que estos aparecen de manera recurrente en determinados puntos de monitoreo y periodos temporales, no fueron eliminados automáticamente, ya que podrían corresponder a eventos reales registrados durante las evaluaciones ambientales.
#
# El dataset resultante conserva información de trazabilidad relevante, incluyendo el informe de origen, la evaluación ambiental, el punto de monitoreo, la fecha, la hora y la ubicación asociada a cada medición.
#
# Finalmente, el conjunto limpio contiene **1,246,271 registros**, equivalentes al 10.93% del dataset original, manteniendo un volumen de información suficiente para las etapas posteriores de preparación de datos, análisis exploratorio y modelado de Machine Learning.
